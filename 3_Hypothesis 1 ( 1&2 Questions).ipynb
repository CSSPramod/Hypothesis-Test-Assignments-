# %% [markdown]
# Q 01: Cutlet Problem

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats
from scipy.stats import norm
import warnings
from PIL import ImageGrab
warnings.filterwarnings("ignore")

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/DS Data Sets/Hypothesis test/Cutlets.csv')

# %%
df
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
df.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
df.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
df.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (0, 2)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unit A, Unit B]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 688.0 bytes

# %%
plt.subplots(figsize=(6,6))
plt.boxplot(df['Unit A'])
plt.title('Unit A')
plt.boxplot(df['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.hist(df['Unit A'], bins=15)
plt.title('Unit A')
# Out:
# Text(0.5, 1.0, 'Unit A')

# %%
plt.hist(df['Unit B'],bins=15, color='green')
plt.title('Unit B')
plt.show()

# %%
labels = ['Unit A', 'Unit B']
sns.distplot(df['Unit A'])
sns.distplot(df['Unit B'])
plt.legend(labels)

# %%
sm.qqplot(df["Unit A"])
plt.title('Unit A')
sm.qqplot(df["Unit B"])
plt.title('Unit B')
plt.show()

# %% [markdown]
# There is no significant difference between two samples.

# %% [markdown]
# Q 02: TAT Problem

# %%
df = pd.read_csv('/content/drive/MyDrive/DS Data Sets/Hypothesis test/LabTAT.csv')

# %%
df.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
df.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
df.isnull().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (0, 4)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Laboratory 1, Laboratory 2, Laboratory 3, Laboratory 4]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
plt.figure(figsize=(6,6))
labels = ['Lab1', 'Lab 2','Lab 3','Lab 4']
sns.distplot(df['Laboratory 1'])
sns.distplot(df['Laboratory 2'])
sns.distplot(df['Laboratory 3'])
sns.distplot(df['Laboratory 4'])
plt.legend(labels)

# %%
sm.qqplot(df['Laboratory 1'])
plt.title('Laboratory 1')
sm.qqplot(df['Laboratory 2'])
plt.title('Laboratory 2')
sm.qqplot(df['Laboratory 3'])
plt.title('Laboratory 3')
sm.qqplot(df['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %%
p_value= stats.f_oneway(df.iloc[:,0], df.iloc[:,1],df.iloc[:,2],df.iloc[:,3])
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
print('p_value',p_value)
# Out:
# p_value F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
# p_value = 2.1156e-57.
#compare it with 0.05.
