# %% [markdown]
# Q 03 == Male Female buyer rations
#
# S 03:

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
from scipy.stats import chi2_contingency

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/DS Data Sets/Hypothesis test/BuyerRatio.csv')

# %%
df
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df.describe()
# Out:
#              East         West        North       South
# count    2.000000     2.000000     2.000000    2.000000
# mean   242.500000   832.500000   743.500000  410.000000
# std    272.236111   976.514465   866.205807  480.832611
# min     50.000000   142.000000   131.000000   70.000000
# 25%    146.250000   487.250000   437.250000  240.000000
# 50%    242.500000   832.500000   743.500000  410.000000
# 75%    338.750000  1177.750000  1049.750000  580.000000
# max    435.000000  1523.000000  1356.000000  750.000000

# %%
# Dimensional Array
obs =np.array([[50,142,131,70],[435,1523,1356,750]])
obs
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
# Chi2 Contengency independence test
chi2_contingency(obs)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
# o/p is (chi2 stat value,p_value,dof, exp.obs)

# %%
#p_value = 0.6603, dof = 3, statistic = 1.5959
observed = [50,142,131,70,435,1523,1356,750]
expected = [42.7653,146.8128,131.1175,72.3042,442.2346,1518.1871,1355.8824,747.6957]

# %%
# compare p_value with alpha = 0.05,
# if p_value=alpha, we reject null hypotheis and if not, we fail to reject null hypothesis.""

# %% [markdown]
#  Q 04 == TeleCall Problem

# %% [markdown]
# S 04:

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
from scipy.stats import chi2_contingency

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/DS Data Sets/Hypothesis test/Costomer+OrderForm.csv')

# %%
df
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
df.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
df.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %%
df.Phillippines.value_counts()
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64

# %%
df.Indonesia.value_counts()
# Out:
# Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64

# %%
df.Malta.value_counts()
# Out:
# Error Free    269
# Defective      31
# Name: Malta, dtype: int64

# %%
df.India.value_counts()
# Out:
# Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
# Contingency table
obs =np.array([[271,267,269,280],[29,33,31,20]])
obs
# Out:
# array([[271, 267, 269, 280],
#        [ 29,  33,  31,  20]])

# %%
#chi2 contingency independence test
chi2_contingency(obs)
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
# o/p is (chi2 stat value, p_value, dof, expected observations)
# statistic = 3.85896, p_value = 0.2771, dof = 3
# observed = [271,267,269,280,29,33,31,20]
# expected = [271.75,271.75,271.75,271.75,28.25,28.25,28.25,28.25]

# %%
# ccompare p_value with alpha=0.05
# if p_value=alpha, we reject null hypothesis and if not, we failed to reject null hypothesis
